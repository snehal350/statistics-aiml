# %%
import pandas as pd
import matplotlib.pyplot as plt

scores = [72, 85, 91, 68, 85, 77,
          85, 90, 62, 95]

df = pd.DataFrame({'Score': scores})

# Summary Statistics
print(df.describe())
print(f"Mode: {df['Score'].mode()[0]}")
# Out:
#            Score
# count  10.000000
# mean   81.000000
# std    10.811516
# min    62.000000
# 25%    73.250000
# 50%    85.000000
# 75%    88.750000
# max    95.000000
# Mode: 85
